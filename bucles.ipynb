# %%
#TITLE Bucle for

# %%
lista ={1,2,3,4,5,6,7}
for elemento in lista:
    print (elemento)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7

# %%
lista ={1,2,3,4,5,6,7}
for e in lista:
    print (e)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7

# %%
lista ={1,2,3,4,5,6,7}
for e in lista:
    valor=e*5
    print ("elemento {}  multiplicado por 5 {}".format(e, valor))
# Out:
# elemento 1  multiplicado por 5 5
# elemento 2  multiplicado por 5 10
# elemento 3  multiplicado por 5 15
# elemento 4  multiplicado por 5 20
# elemento 5  multiplicado por 5 25
# elemento 6  multiplicado por 5 30
# elemento 7  multiplicado por 5 35
