# %%
import pandas as pd
import numpy as np

# Crear array NumPy 2D
datapromedio=[]
datapromedio.append(1)
datapromedio.append(2)
datapromedio.append(3)
data = np.array([datapromedio])
columnas=['A', 'B', 'C']
# Convertir a DataFrame con nombres de columnas
df = pd.DataFrame(data, columns=columnas)
print(df)
# Out:
#    A  B  C
# 0  1  2  3
