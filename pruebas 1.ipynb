# %%
nombre ="luis"
print("mi nonbre es {}".format(nombre))
# Out:
# mi nonbre es luis

# %%
nombre ="otro"
print("mi nonbre es {variable}".format(variable=nombre))
# Out:
# mi nonbre es otro

# %%
nombre ="otro"
print(nombre[0])
print(nombre[1])
print(nombre[2])
print(nombre[3])
print(nombre[-1])
print(nombre[-2])
# Out:
# o
# t
# r
# o
# o
# r

# %%
nombre ="otro"
print(nombre[0:2])
# Out:
# ot
