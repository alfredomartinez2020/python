# %%
# !pip install openpyxl
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 250.9/250.9 KB 2.1 MB/s eta 0:00:000:00:01m eta 0:00:01
# ...

# %%
import pandas as pd

# %%
#/home/casa/Escritorio/DESKTOP ALFREDO/Learning PAth/Python
 
dataframe = pd.read_excel('Ejemplo_excel.xlsx')

dataframe
# Out:
#    Unnamed: 0   a   b   c   d
# 0           0   0   1   2   3
# 1           1   4   5   6   7
# 2           2   8   9  10  11
# 3           3  12  13  14  15

# %%
dataframe['e']=[20,30,40,50]
dataframe
# Out:
#    Unnamed: 0   a   b   c   d   e
# 0           0   0   1   2   3  20
# 1           1   4   5   6   7  30
# 2           2   8   9  10  11  40
# 3           3  12  13  14  15  50

# %%
dataframe.to_excel('salida_excel.xlsx', sheetname)
