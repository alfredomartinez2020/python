# %%
import numpy as np
array=np.arange(0,10)

array

condicion=array>5

condicion
# Out:
# array([False, False, False, False, False, False,  True,  True,  True,
#         True])

# %%
array[condicion]
# Out:
# array([6, 7, 8, 9])

# %%
array[array>5]
# Out:
# array([6, 7, 8, 9])

# %%
array[array % 2 ==0]
# Out:
# array([0, 2, 4, 6, 8])
