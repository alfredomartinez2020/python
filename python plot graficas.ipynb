# %%
import numpy as np
import pandas as pd

dataframe = pd.DataFrame(np.random.randint(200, size=(50, 4))  ,  columns=['a', 'b', 'c', '2'])
dataframe
# Out:
#       a    b    c    2
# 0   133   36  107   53
# 1    45   53  116    5
# 2     9   85   68  198
# 3    59   66  167  121
# 4   144   46   58   76
# 5   119   71  144   70
# 6    51  106   40  191
# 7   120   42   92  173
# 8    26  142  155  185
# 9   180   31   27   16
# 10   40  179  175   99
# 11  175  188  119  116
# 12  189   50   26   46
# 13  198  165  172   92
# 14   29   49  148  125
# 15  157   16  122  193
# 16  167  122  106   38
# 17  189    4   97  162
# 18  181  140   63  178
# 19  195  133   16    8
# 20  108   82   84   92
# 21  157   91  118  162
# 22  166  197  106   28
# 23   68   68   48   53
# 24   41   88   52   53
# 25  106   75   11  191
# 26  140  176  176  127
# 27   39   73  142   23
# 28  163  195   98   38
# 29   56   18    2  108
# 30   16  158   88   15
# 31   19   37   59  146
# 32  146  193  101   89
# 33   93  111   49   51
# 34  144  102  133  175
# 35  110   11   31   43
# 36    0  139  122    5
# 37  136   50   25  194
# 38    3   24   18   21
# ...

# %%
pip install matplotlib
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.8/8.8 MB 5.4 MB/s eta 0:00:000m eta 0:00:010:01:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 5.9 MB/s eta 0:00:000m eta 0:00:010:01:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 122.8/122.8 KB 937.5 kB/s eta 0:00:0031m15.0 MB/s eta 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 7.5 MB/s eta 0:00:000m eta 0:00:010:01:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 325.0/325.0 KB 3.5 MB/s eta 0:00:000:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.1/7.1 MB 8.1 MB/s eta 0:00:000m eta 0:00:010:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
dataframe['a'].hist()
# Out:
# <Axes: >

# %%
dataframe['a'].hist(bins=30)
# Out:
# <Axes: >

# %%
dataframe['a'].plot.hist(bins=30)
# Out:
# <Axes: ylabel='Frequency'>

# %%
dataframe.plot.area()
# Out:
# <Axes: >

# %%
dataframe.plot.area(alpha=0.3)
# Out:
# <Axes: >

# %%
dataframe.plot.bar()
# Out:
# <Axes: >

# %%
dataframe.plot.bar(stacked=True)
# Out:
# <Axes: >

# %%
dataframe.plot.scatter(  x='a', y='b', c='c')
# Out:
# <Axes: xlabel='a', ylabel='b'>

# %%
dataframe.plot.scatter(  x='a', y='b', c='c', cmap ='coolwarm')
# Out:
# <Axes: xlabel='a', ylabel='b'>

# %%
dataframe.plot.box()
# Out:
# <Axes: >

# %%
dataframe.plot.hexbin(x='a', y='b', gridsize=12)
# Out:
# <Axes: xlabel='a', ylabel='b'>

# %%
pip install scipy
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.7/37.7 MB 1.9 MB/s eta 0:00:00m eta 0:00:010:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
dataframe.plot.kde()
# Out:
# <Axes: ylabel='Density'>

# %%
dataframe.plot.density()
# Out:
# <Axes: ylabel='Density'>
