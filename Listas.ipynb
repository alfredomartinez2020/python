# %%
[1,2,3]
# Out:
# [1, 2, 3]

# %%
["1", "2", "3"]
# Out:
# ['1', '2', '3']

# %%
lista = ["1", "2", "3"]
lista.append("4" )

lista
# Out:
# ['1', '2', '3', '4']

# %%
lista[0]
lista[-1]
lista[0:3]
# Out:
# ['1', '2', '3']

# %%
listadoble=[1, 2, 3, ['1en lista doble', '2', '3', '4']]

# %%
listadoble
# Out:
# [1, 2, 3, ['1en lista doble', '2', '3', '4']]

# %%
listadoble[3][0]
# Out:
# '1en lista doble'

# %%
lista[0]=5

lista
# Out:
# [5, '2', '3', '4']
