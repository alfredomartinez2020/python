# %%
5==1
# Out:
# False

# %%
3>2
# Out:
# True

# %%
2<1
# Out:
# False

# %%
3>=2
# Out:
# True

# %%
2!=4
# Out:
# True

# %%
(2<1) and (2==4)
# Out:
# False

# %%
(2<4) and (4==4)
# Out:
# True

# %%
(10<4) or (4==4)
# Out:
# True
