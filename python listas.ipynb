# %%
lista1=[1,2,3]

lista2=[]

lista2=lista1

lista2
# Out:
# [1, 2, 3]

# %%
lista1=[100,2,3,5,6,8,10]

lista2=[]


for numero in lista1:
    valor=numero * 2
    lista2.append(valor)

lista2.sort()

lista2
# Out:
# [4, 6, 10, 12, 16, 20, 200]

# %%
names = ["Alice", "Bob", "Charlie"]
sorted_names = sorted(names, reverse=True)

sorted_names
# Out:
# ['Charlie', 'Bob', 'Alice']

# %%
lista1=[100,2,3,5,6,8,10]

lista2=[]


for numero in lista1:
    valor=numero * 2
    lista2.append(valor)




lista2.sort(reverse=True)

lista2
# Out:
# [200, 20, 16, 12, 10, 6, 4]

# %%
lista1=[100,2,3,5,6,8,10]
lista3=[numero * 2 for numero in lista1 ]
lista3
# Out:
# [200, 4, 6, 10, 12, 16, 20]
