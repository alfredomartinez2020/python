# %%
a=5
b=7
if(a==b):
    print("a==b")
else:
    print("no son iguales")
# Out:
# no son iguales

# %%
a=7
b=7
if(a==b):
    print("a==b")
else:
    print("no son iguales")
# Out:
# a==b

# %%
a=10
b=10
if(a==b):
    print("a==b")
elif (a<b ):
    print("a es menor")
elif (a>b ):
    print("a es menor")
# Out:
# a==b
