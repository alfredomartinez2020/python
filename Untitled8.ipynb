# %%
#manejo de nulls

import numpy as np
import pandas as pd

diccionario  = { 'A': [4,5, np.nan] , 'B': [4,9, 3] , 'C': [np.nan,66, np.nan] }


diccionario


dataframe=pd.DataFrame(diccionario)
dataframe
# Out:
#      A  B     C
# 0  4.0  4   NaN
# 1  5.0  9  66.0
# 2  NaN  3   NaN

# %%
dataframe.dropna()
# Out:
#      A  B     C
# 1  5.0  9  66.0

# %%
dataframe.dropna(axis=1)
# Out:
#    B
# 0  4
# 1  9
# 2  3

# %%
dataframe.fillna(value=100)
# Out:
#        A  B      C
# 0    4.0  4  100.0
# 1    5.0  9   66.0
# 2  100.0  3  100.0

# %%
valormedio=dataframe.mean()
valormedio
# Out:
# A     4.500000
# B     5.333333
# C    66.000000
# dtype: float64

# %%
dataframe.fillna(value=valormedio)
# Out:
#      A  B     C
# 0  4.0  4  66.0
# 1  5.0  9  66.0
# 2  4.5  3  66.0
