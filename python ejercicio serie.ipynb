# %%
import numpy as np
import pandas as pd

asignaturas =['matematicas','fisica','historia']

notas =[9,9,8]

serie =pd.Series(data=notas, index=asignaturas)

serie
# Out:
# matematicas    9
# fisica         9
# historia       8
# dtype: int64

# %%
nota_fisica= serie['fisica']
nota_fisica
print('nota de fisica {} '.format(nota_fisica))
# Out:
# nota de fisica 9
