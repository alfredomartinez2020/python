# %%
import numpy as np
import pandas as pd

ventas_enero = np.random.randint(100, 500, 3)
ventas_feb = np.random.randint(100, 500, 3)
ventas_marzo = np.random.randint(100, 500, 3)
filas = ['enero','feb','marzo']
cols = ['oficina1','oficina2','oficina3']
#ventas = ['oficina1','oficina2','oficina3']

# %%
ventas_enero
# Out:
# array([197, 152, 416])

# %%
ventas =[ventas_enero, ventas_feb, ventas_marzo]

# %%
dataframe = pd.DataFrame(ventas, filas, cols )
dataframe
# Out:
#        oficina1  oficina2  oficina3
# enero       379       188       296
# feb         280       291       362
# marzo       140       249       307

# %%
dataframe['oficina1']['enero']
# Out:
# np.int64(379)

# %%
dataframe.sum(axis=1)
# Out:
# enero    863
# feb      933
# marzo    696
# dtype: int64

# %%
dataframe.sum(axis=0)
# Out:
# oficina1    799
# oficina2    728
# oficina3    965
# dtype: int64
