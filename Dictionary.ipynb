# %%
Diccionario = {'clave':'valor1', 'clave2':'valor2'}

# %%
Diccionario
# Out:
# {'clave': 'valor1', 'clave2': 'valor2'}

# %%
Diccionario['clave']
# Out:
# 'valor1'

# %%
Diccionario1 = {'nombre':'nombre', 'edad':30}

print(Diccionario1['nombre'])
Diccionario1['edad']
# Out:
# nombre
# 30
