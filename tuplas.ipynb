# %%
tupla=(1,2,3,4)
tupla
# Out:
# (1, 2, 3, 4)

# %%
tupla[0]
# Out:
# 1

# %%
tupla[0]=2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 tupla[0]=2
#
# TypeError: 'tuple' object does not support item assignment
