# %%
pip install html5lib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
import pandas as pd

response = requests.get('https://es.wikipedia.org/wiki/Anexo:Pa%C3%ADses_y_territorios_dependientes_por_poblaci%C3%B3n')
html_content = response.text # Returns the HTML as a string
print(html_content)
# Out:
# Please set a user-agent and respect our robot policy https://w.wiki/4wJS. See also https://phabricator.wikimedia.org/T400119.

# %%
import urllib.request
with urllib.request.urlopen('https://www.example.com') as response:
   html_bytes = response.read()
   html_content = html_bytes.decode('utf-8')
print(html_content)
# Out:
# <!doctype html><html lang="en"><head><title>Example Domain</title><meta name="viewport" content="width=device-width, initial-scale=1"><style>body{background:#eee;width:60vw;margin:15vh auto;font-family:system-ui,sans-serif}h1{font-size:1.5em}div{opacity:0.8}a:link,a:visited{color:#348}</style></head><body><div><h1>Example Domain</h1><p>This domain is for use in documentation examples without needing permission. Avoid use in operations.</p><p><a href="https://iana.org/domains/example">Learn more</a></p></div></body></html>

# %%
import requests
from bs4 import BeautifulSoup

r = requests.get('https://learn.microsoft.com/es-es/training/azure/')
soup = BeautifulSoup(r.text, 'lxml')

soup
# Out:
# <!DOCTYPE html>
# <html class="layout layout-single topiclanding show-breadcrumb default-focus" data-auth-status-determined="false" data-authenticated="false" data-target="docs" dir="ltr" lang="es-es" x-ms-format-detection="none">
# <head>
# <title>Entrenamiento para Azure | Microsoft Learn</title>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <meta content="light dark" name="color-scheme"/>
# <meta content="Desarrolla tus habilidades para crear y administrar aplicaciones en la nube, en el entorno local y en el perÃ­metro." name="description"/>
# <link href="https://learn.microsoft.com/es-es/training/azure/" rel="canonical"/>
# <!-- Non-customizable open graph and sharing-related metadata -->
# <meta content="summary_large_image" name="twitter:card"/>
# <meta content="@MicrosoftLearn" name="twitter:site"/>
# <meta content="website" property="og:type"/>
# <meta content="Microsoft Learn" property="og:image:alt"/>
# ...
