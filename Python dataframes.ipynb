# %%
######dataframes como tablas

# %%
import numpy as np
import pandas as pd
filas =[   'ventas1','ventas2','ventas3' ]
columnas =[   'zona1','zona2','zona3' ]

datos =[   [123,4564,6545] , [123,4564,6545] , [123,4564,6545]  ]

# %%
dataframe= pd.DataFrame(datos, filas, columnas)
dataframe
# Out:
#          zona1  zona2  zona3
# ventas1    123   4564   6545
# ventas2    123   4564   6545
# ventas3    123   4564   6545

# %%
dataframe.loc['ventas1']
# Out:
# zona1     123
# zona2    4564
# zona3    6545
# Name: ventas1, dtype: int64

# %%
dataframe.loc[['ventas1', 'ventas2']]
# Out:
#          zona1  zona2  zona3
# ventas1    123   4564   6545
# ventas2    123   4564   6545

# %%
dataframe['zona1']
# Out:
# ventas1    123
# ventas2    123
# ventas3    123
# Name: zona1, dtype: int64

# %%
dataframe[['zona1', 'zona2']]
# Out:
#          zona1  zona2
# ventas1    123   4564
# ventas2    123   4564
# ventas3    123   4564

# %%
dataframe.loc['ventas1']['zona1']
# Out:
# np.int64(123)

# %%
dataframe['todaslaszonas']=dataframe['zona1']+dataframe['zona2']+dataframe['zona3'] 

dataframe
# Out:
#          zona1  zona2  zona3  todaslaszonas
# ventas1    123   4564   6545          11232
# ventas2    123   4564   6545          11232
# ventas3    123   4564   6545          11232

# %%
dataframe.drop('todaslaszonas', axis=1)
# Out:
#          zona1  zona2  zona3
# ventas1    123   4564   6545
# ventas2    123   4564   6545
# ventas3    123   4564   6545

# %%
dataframe.drop('todaslaszonas', axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 dataframe.drop('todaslaszonas', axis=1, inplace=True)
#       2 dataframe
#
# File ~/jupyter_env/lib/python3.10/site-packages/pandas/core/frame.py:5603, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5455 def drop(
#    5456     self,
#    5457     labels: IndexLabel | None = None,
#    (...)
#    5464     errors: IgnoreRaise = "raise",
#    5465 ) -> DataFrame | None:
#    5466     """
#    5467     Drop specified labels from rows or columns.
#    5468
#    (...)
#    5601             weight  1.0     0.8
#    5602     """
# -> 5603     return super().drop(
#    5604         labels=labels,
#    5605         axis=axis,
#    5606         index=index,
#    5607         columns=columns,
#    5608         level=level,
#    5609         inplace=inplace,
# ...

# %%
dataframe
# Out:
#          zona1  zona2  zona3
# ventas1    123   4564   6545
# ventas2    123   4564   6545
# ventas3    123   4564   6545

# %%
dataframe.drop('ventas1', inplace=True)

# %%
dataframe
# Out:
#          zona1  zona2  zona3
# ventas2    123   4564   6545
# ventas3    123   4564   6545
