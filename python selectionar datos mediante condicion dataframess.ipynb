# %%
#selectionar datos mediante condicion dataframess

# %%
import pandas as pd
filas = 'ventas1 ventas2 ventas3'.split()
filas
 

columnas  = 'zona1 zona2 zona3'.split()
columnas

datos = [   [123,  200,  455] , [123,  44,  300] , [123,  55,  100]   ]

datos

dataframe = pd.DataFrame(datos, filas, columnas)
dataframe
# Out:
#          zona1  zona2  zona3
# ventas1    123    200    455
# ventas2    123     44    300
# ventas3    123     55    100

# %%
columnas  = 'zona1 zona2 zona3'.split()
columnas
# Out:
# ['zona1', 'zona2', 'zona3']

# %%
datos = [   [123,  200,  455] , [123,  44,  300] , [123,  55,  100]   ]

datos
# Out:
# [[123, 200, 455], [123, 44, 300], [123, 55, 100]]

# %%
dataframe = pd.DataFrame(datos, filas, columnas)
dataframe
# Out:
#          zona1  zona2  zona3
# ventas1    123    200    455
# ventas2    123     44    300
# ventas3    123     55    100

# %%
condicion = dataframe>200
dataframe[condicion]
# Out:
#          zona1  zona2  zona3
# ventas1    NaN  45644    455
# ventas2    NaN  45644    455
# ventas3    NaN  45644    455

# %%
condicion = dataframe['zona1']>100
dataframe[condicion]
# Out:
#          zona1  zona2  zona3
# ventas1    123    200    455
# ventas2    123     44    300
# ventas3    123     55    100

# %%
condicion = ( dataframe['zona1']>50)   & ( dataframe['zona3']>300)   
dataframe[condicion]
# Out:
#          zona1  zona2  zona3
# ventas1    123    200    455

# %%
condicion = ( dataframe['zona1']>50)   | ( dataframe['zona3']>300)   
dataframe[condicion]
# Out:
#          zona1  zona2  zona3
# ventas1    123    200    455
# ventas2    123     44    300
# ventas3    123     55    100

# %%
condicion = ( dataframe['zona1']>50)   | ( dataframe['zona3']>300)   
dataframe[condicion]['zona1']
# Out:
# ventas1    123
# ventas2    123
# ventas3    123
# Name: zona1, dtype: int64

# %%
condicion = ( dataframe['zona1']>50)   | ( dataframe['zona3']>300)   
dataframe[condicion][[  'zona1' , 'zona2']]
# Out:
#          zona1  zona2
# ventas1    123    200
# ventas2    123     44
# ventas3    123     55

# %%
import pandas as pd
filas = 'ventas1 ventas2 ventas3'.split()
filas
 

columnas  = 'zona1 zona2 zona3'.split()
columnas

datos = [   [123,  200,  455] , [123,  44,  300] , [123,  55,  100]   ]

datos

dataframe = pd.DataFrame(datos, filas, columnas)
dataframe
# Out:
#          zona1  zona2  zona3
# ventas1    123    200    455
# ventas2    123     44    300
# ventas3    123     55    100

# %%
diasfilas = 'dia1 dia2 dia3'.split()
dataframe['dias']=diasfilas

dataframe
# Out:
#          zona1  zona2  zona3  dias
# ventas1    123    200    455  dia1
# ventas2    123     44    300  dia2
# ventas3    123     55    100  dia3

# %%
dataframe.set_index('dias')
# Out:
#       zona1  zona2  zona3
# dias
# dia1    123    200    455
# dia2    123     44    300
# dia3    123     55    100
