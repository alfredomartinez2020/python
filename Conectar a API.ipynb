# %%
pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Using cached pandas-2.3.3-cp310-cp310-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (12.8 MB)
# ...
#   Using cached numpy-2.2.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.8 MB)
# ...
#   Using cached tzdata-2026.2-py2.py3-none-any.whl (349 kB)
# ...
# ERROR: Operation cancelled by user
# ^C
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Import Librerias

# %%
import requests 
import json
from pandas import json_normalize
import pandas as pd
import random
import string

# %% [markdown]
# CODE call API

# %%
respuesta=requests.get('https://api.agify.io/?name='+nombre)
print(respuesta)
data=respuesta.json()
data
df=json_normalize(data)
df
# Out:
# <Response [429]>
#                    error
# 0  Request limit reached

# %%
df
# Out:
#         count      name   age                  error
# 0    179232.0      luis    63                    NaN
# 1         0.0  {nombre}  None                    NaN
# 2         0.0  {nombre}  None                    NaN
# 3         0.0  {nombre}  None                    NaN
# 4         0.0  {nombre}  None                    NaN
# ..        ...       ...   ...                    ...
# 199       NaN       NaN   NaN  Request limit reached
# 200       NaN       NaN   NaN  Request limit reached
# 201       NaN       NaN   NaN  Request limit reached
# 202       NaN       NaN   NaN  Request limit reached
# 203       NaN       NaN   NaN  Request limit reached
#
# [204 rows x 4 columns]

# %%
data['age']
df=json_normalize(data)
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 data['age']
#       2 df=json_normalize(data)
#       3 df
#
# KeyError: 'age'
